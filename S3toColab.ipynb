# %%
# !pip install boto3

# %%
import boto3
import botocore

BUCKET_NAME = 'gyneye-dev' # replace with your bucket name

# enter authentication credentials
s3 = boto3.resource('s3', aws_access_key_id = 'AKIASLS7V62SNT674NPM', 
                          aws_secret_access_key= 'QAk6lw2G+9zoWLWIModrruIPdNiQAnDpfc5KCgZP')

# %%
KEY = '119 ST high ac T3 S3.jpg' # replace with your object key

try:
  # we are trying to download training dataset from s3 with name `my-training-data.csv` 
  # to colab dir with name `training.csv`
  s3.Bucket(BUCKET_NAME).download_file(KEY, '119 ST high ac T3 S3.jpg')
  
except botocore.exceptions.ClientError as e:
  if e.response['Error']['Code'] == "404":
    print("The object does not exist.")
  else:
    raise
# Out:
# The object does not exist.
